# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/combined/recession_probability.csv', parse_dates=['date'])

# %%
display(df.head())
display(df.info())
display(df.describe())
# Out:
#         date  recession_probability  1_month_recession_probability  \
# 0 1967-02-01                    NaN                            NaN
# 1 1967-03-01                    NaN                            NaN
# 2 1967-04-01                    NaN                            NaN
# 3 1967-05-01                    NaN                            0.8
# 4 1967-06-01                    0.8                            0.5
#
#    3_month_recession_probability  6_month_recession_probability  1_year_rate  \
# 0                            NaN                           0.00     4.574444
# 1                           0.80                           0.26     4.185000
# 2                           0.50                           0.08     3.898500
# 3                           0.00                           0.00     3.885000
# 4                           0.26                           0.00     4.164545
#
#    3_months_rate  6_months_rate   CPI   INDPRO  10_year_rate  share_price  \
# 0       4.561111       4.590556  33.0  34.7650          4.63     4.733288
# 1       4.259091       4.221818  33.0  34.5691          4.54     4.854181
# 2       3.837500       3.894500  33.1  34.8951          4.59     4.943822
# 3       3.603182       3.799545  33.1  34.5907          4.85     5.050295
# 4       3.535909       3.889545  33.3  34.5863          5.02     5.005238
#
#    unemployment_rate   PPI  OECD_CLI_index  CSI_index Business_Quarter  \
# 0                3.8  27.2       98.590266       94.1               Q1
# 1                3.8  27.2       98.606358       94.1               Q1
# 2                3.8  27.2       98.745387       94.1               Q2
# 3                3.8  27.2       98.993997       95.9               Q2
# 4                3.9  27.2       99.304794       95.9               Q2
#
#       Month Country
# 0  February     USA
# 1     March     USA
# 2     April     USA
# 3       May     USA
# 4      June     USA
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   date                           700 non-null    datetime64[ns]
#  1   recession_probability          696 non-null    float64
#  2   1_month_recession_probability  696 non-null    float64
#  3   3_month_recession_probability  696 non-null    float64
#  4   6_month_recession_probability  694 non-null    float64
#  5   1_year_rate                    621 non-null    float64
#  6   3_months_rate                  700 non-null    float64
#  7   6_months_rate                  700 non-null    float64
#  8   CPI                            700 non-null    float64
#  9   INDPRO                         700 non-null    float64
#  10  10_year_rate                   700 non-null    float64
#  11  share_price                    700 non-null    float64
#  12  unemployment_rate              700 non-null    float64
#  13  PPI                            700 non-null    float64
#  14  OECD_CLI_index                 700 non-null    float64
#  15  CSI_index                      700 non-null    float64
#  16  Business_Quarter               700 non-null    object
#  17  Month                          700 non-null    object
#  18  Country                        700 non-null    object
# dtypes: datetime64[ns](1), float64(15), object(3)
# memory usage: 104.0+ KB
# None
#                       date  recession_probability  \
# count                  700             696.000000
# mean   1996-03-16 18:28:48               8.464483
# min    1967-02-01 00:00:00               0.000000
# 25%    1981-08-24 06:00:00               0.020000
# 50%    1996-03-16 12:00:00               0.120000
# 75%    2010-10-08 18:00:00               0.580000
# max    2025-05-01 00:00:00             100.000000
# std                    NaN              23.267073
#
#        1_month_recession_probability  3_month_recession_probability  \
# count                     696.000000                     696.000000
# mean                        8.464483                       8.464483
# min                         0.000000                       0.000000
# 25%                         0.020000                       0.020000
# 50%                         0.120000                       0.120000
# 75%                         0.580000                       0.580000
# max                       100.000000                     100.000000
# std                        23.267073                      23.267073
#
#        6_month_recession_probability  1_year_rate  3_months_rate  \
# count                     694.000000   621.000000     700.000000
# mean                        8.487003     4.893173       4.498286
# min                         0.000000     0.049500       0.011429
# 25%                         0.020000     2.196364       1.651347
# 50%                         0.110000     5.182857       4.823964
# 75%                         0.580000     6.903810       6.152500
# max                       100.000000    14.699524      16.304500
# std                        23.296829     3.271484       3.285634
#
#        6_months_rate         CPI      INDPRO  10_year_rate  share_price  \
# count     700.000000  700.000000  700.000000    700.000000   700.000000
# mean        4.621415  155.196477   73.564175      5.974614    50.352532
# min         0.035500   33.000000   34.507600      0.620000     3.506448
# 25%         1.768092   92.875000   51.036550      3.727500     7.103287
# 50%         4.935714  155.800000   73.934900      5.830000    34.323595
# 75%         6.414145  219.173750   97.622350      7.780000    78.384862
# max        15.516190  320.580000  104.103800     15.320000   187.784900
# std         3.277224   79.135813   23.657317      3.036469    47.206401
#
#        unemployment_rate         PPI  OECD_CLI_index   CSI_index
# count         700.000000  700.000000      700.000000  700.000000
# mean            5.952143  177.175307       99.913584   84.186286
# min             3.400000   27.200000       92.843120   50.000000
# 25%             4.600000   90.100000       99.150722   74.275000
# 50%             5.700000  126.500000      100.056756   87.100000
# 75%             7.200000  265.200000      100.854196   93.825000
# max            14.800000  640.992000      103.812665  112.000000
# std             1.754596  136.079032        1.477831   12.948403

# %%
missing = df.isnull().sum()
display(missing[missing > 0])
# Out:
# recession_probability             4
# 1_month_recession_probability     4
# 3_month_recession_probability     4
# 6_month_recession_probability     6
# 1_year_rate                      79
# dtype: int64

# %%
plt.figure(figsize=(12,5))
plt.plot(df['date'], df['recession_probability'], label='Recession Probability')
plt.xlabel('Date')
plt.ylabel('Probability (%)')
plt.title('Recession Probability Over Time')
plt.legend()
plt.show()

# %%
econ_cols = ['recession_probability','CPI','INDPRO','unemployment_rate','PPI','OECD_CLI_index','share_price']
plt.figure(figsize=(10,7))
sns.heatmap(df[econ_cols].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of Economic Indicators')
plt.show()

# %%
for col in econ_cols[1:]:
    plt.figure(figsize=(10,4))
    plt.plot(df['date'], df[col])
    plt.xlabel('Date')
    plt.ylabel(col)
    plt.title(f'{col} Over Time')
    plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x='unemployment_rate', y='recession_probability', data=df)
plt.title('Unemployment Rate vs. Recession Probability')
plt.show()

# %%
plt.plot(df['date'], df['CPI'], label='CPI')
plt.plot(df['date'], df['INDPRO'], label='Industrial Production')
plt.plot(df['date'], df['PPI'], label='PPI')
plt.plot(df['date'], df['OECD_CLI_index'], label='OECD CLI Index')
plt.plot(df['date'], df['share_price'], label='Share Price')
plt.xlabel('Date')
plt.legend()
plt.show()

# %%
for indicator in econ_cols[1:]:
    fig, ax1 = plt.subplots(figsize=(10,5))
    ax2 = ax1.twinx()

    ax1.plot(df['date'], df['recession_probability'], color='tab:blue', label='Recession Probability')
    ax2.plot(df['date'], df[indicator], color='tab:orange', label=indicator)

    ax1.set_xlabel('Date')
    ax1.set_ylabel('Recession Probability', color='tab:blue')
    ax2.set_ylabel(indicator, color='tab:orange')
    plt.title(f'Recession Probability and {indicator} Over Time')

    fig.tight_layout()
    plt.show()
