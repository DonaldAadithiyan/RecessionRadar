# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import acf
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.cluster import hierarchy
from scipy.spatial.distance import squareform

# %%
processed_recession_df = pd.read_csv('../data/processed/recession_probability.csv')

# %%
processed_recession_df.columns
# Out:
# Index(['date', 'recession_probability', '1_month_recession_probability',
#        '3_month_recession_probability', '6_month_recession_probability',
#        '1_year_rate', '3_months_rate', '6_months_rate', 'CPI', 'INDPRO',
#        '10_year_rate', 'share_price', 'unemployment_rate', 'PPI',
#        'OECD_CLI_index', 'CSI_index', 'Year', 'Quarter_Number', 'Month_Number',
#        'gdp_per_capita', 'seasonally_adjusted_INDPRO',
#        'seasonally_adjusted_CPI', 'seasonally_adjusted_unemployment_rate',
#        'anomaly_INDPRO', 'anomaly_CPI', 'anomaly_unemployment_rate',
#        'anomaly_PPI', 'anomaly_share_price', 'anomaly_1_year_rate',
#        'anomaly_3_months_rate', 'anomaly_6_months_rate',
#        'anomaly_10_year_rate', 'CPI_trend', 'INDPRO_trend',
#        'unemployment_rate_trend', 'PPI_trend', 'seasonally_adjusted_PPI'],
#       dtype='object')

# %%
# Assuming processed_recession_df is already loaded

acf_columns = [
    '1_year_rate', 
    '3_months_rate', 
    '6_months_rate', 
    'CPI', 
    'INDPRO', 
    '10_year_rate', 
    'share_price', 
    'unemployment_rate', 
    'PPI', 
    'OECD_CLI_index', 
    'CSI_index', 
    'gdp_per_capita'
]

from statsmodels.tsa.stattools import acf
import numpy as np
import pandas as pd

def get_acf_features_rolling(series, nlags=10, seasonal_lag=None):
    """
    Compute time-dependent ACF features safely for each time step
    using only past data (no leakage).
    """
    series = pd.Series(series)
    results = {
        "acf1_original": [],
        "sumsq_acf_original": [],
        "acf1_diff1": [],
        "sumsq_acf_diff1": [],
        "acf1_diff2": [],
        "sumsq_acf_diff2": [],
        "acf_seasonal": []
    }

    for t in range(len(series)):
        hist = series.iloc[:t+1].dropna()   # use only history up to time t

        if len(hist) < nlags + 1:
            # not enough history yet
            for k in results.keys():
                results[k].append(np.nan)
            continue

        # ACF for original
        acf_original = acf(hist, nlags=nlags, fft=False)
        results["acf1_original"].append(acf_original[1])
        results["sumsq_acf_original"].append(np.sum(acf_original[1:11] ** 2))

        # First difference
        diff1 = hist.diff().dropna()
        if len(diff1) > nlags:
            acf_diff1 = acf(diff1, nlags=nlags, fft=False)
            results["acf1_diff1"].append(acf_diff1[1])
            results["sumsq_acf_diff1"].append(np.sum(acf_diff1[1:11] ** 2))
        else:
            results["acf1_diff1"].append(np.nan)
            results["sumsq_acf_diff1"].append(np.nan)

        # Second difference
        diff2 = diff1.diff().dropna()
        if len(diff2) > nlags:
            acf_diff2 = acf(diff2, nlags=nlags, fft=False)
            results["acf1_diff2"].append(acf_diff2[1])
            results["sumsq_acf_diff2"].append(np.sum(acf_diff2[1:11] ** 2))
        else:
            results["acf1_diff2"].append(np.nan)
            results["sumsq_acf_diff2"].append(np.nan)

        # Seasonal autocorrelation
        if seasonal_lag is not None and seasonal_lag < len(acf_original):
            results["acf_seasonal"].append(acf_original[seasonal_lag])
        else:
            results["acf_seasonal"].append(np.nan)

    return pd.DataFrame(results)


# ✅ Apply safely to each column
for col in acf_columns:
    acf_feats = get_acf_features_rolling(processed_recession_df[col], nlags=10, seasonal_lag=12)
    for k in acf_feats.columns:
        processed_recession_df[f"{col}_{k}"] = acf_feats[k]

print(processed_recession_df.head())
# Out:
# /Users/donaldaadithiyan/Personal learn dev/RecessionRadar/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:691: RuntimeWarning: invalid value encountered in divide
#   acf = avf[: nlags + 1] / avf[0]
#          date  recession_probability  1_month_recession_probability  \
# 0  1967-02-01                    NaN                            NaN
# 1  1967-03-01                    NaN                            NaN
# 2  1967-04-01                    NaN                            NaN
# 3  1967-05-01                    NaN                            0.8
# 4  1967-06-01                    0.8                            0.5
#
#    3_month_recession_probability  6_month_recession_probability  1_year_rate  \
# 0                            NaN                           0.00     4.574444
# 1                           0.80                           0.26     4.185000
# 2                           0.50                           0.08     3.898500
# 3                           0.00                           0.00     3.885000
# 4                           0.26                           0.00     4.164545
#
#    3_months_rate  6_months_rate   CPI   INDPRO  ...  CSI_index_acf1_diff2  \
# 0       4.561111       4.590556  33.0  34.7650  ...                   NaN
# 1       4.259091       4.221818  33.0  34.5691  ...                   NaN
# 2       3.837500       3.894500  33.1  34.8951  ...                   NaN
# 3       3.603182       3.799545  33.1  34.5907  ...                   NaN
# 4       3.535909       3.889545  33.3  34.5863  ...                   NaN
#
#    CSI_index_sumsq_acf_diff2  CSI_index_acf_seasonal  \
# 0                        NaN                     NaN
# 1                        NaN                     NaN
# 2                        NaN                     NaN
# 3                        NaN                     NaN
# 4                        NaN                     NaN
#
#    gdp_per_capita_acf1_original  gdp_per_capita_sumsq_acf_original  \
# 0                           NaN                                NaN
# 1                           NaN                                NaN
# 2                           NaN                                NaN
# 3                           NaN                                NaN
# 4                           NaN                                NaN
#
#    gdp_per_capita_acf1_diff1  gdp_per_capita_sumsq_acf_diff1  \
# 0                        NaN                             NaN
# 1                        NaN                             NaN
# 2                        NaN                             NaN
# 3                        NaN                             NaN
# 4                        NaN                             NaN
#
#    gdp_per_capita_acf1_diff2  gdp_per_capita_sumsq_acf_diff2  \
# 0                        NaN                             NaN
# 1                        NaN                             NaN
# 2                        NaN                             NaN
# 3                        NaN                             NaN
# 4                        NaN                             NaN
#
#    gdp_per_capita_acf_seasonal
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
# [5 rows x 121 columns]

# %%
processed_recession_df.columns
# Out:
# Index(['date', 'recession_probability', '1_month_recession_probability',
#        '3_month_recession_probability', '6_month_recession_probability',
#        '1_year_rate', '3_months_rate', '6_months_rate', 'CPI', 'INDPRO',
#        ...
#        'CSI_index_acf1_diff2', 'CSI_index_sumsq_acf_diff2',
#        'CSI_index_acf_seasonal', 'gdp_per_capita_acf1_original',
#        'gdp_per_capita_sumsq_acf_original', 'gdp_per_capita_acf1_diff1',
#        'gdp_per_capita_sumsq_acf_diff1', 'gdp_per_capita_acf1_diff2',
#        'gdp_per_capita_sumsq_acf_diff2', 'gdp_per_capita_acf_seasonal'],
#       dtype='object', length=121)

# %%
processed_recession_df.to_csv('../data/feature-engineered/recession_probability.csv', index=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(20, 16))  # Bigger figure for 121 columns

sns.heatmap(
    corr_matrix,
    cmap='coolwarm',
    center=0,
    square=True,
    linewidths=0.2,
    cbar_kws={"shrink": 0.5},
    xticklabels=True,
    yticklabels=True
)

plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.title("Correlation Matrix Heatmap (121 features)")
plt.tight_layout()
plt.show()

# %%
processed_recession_df.shape
# Out:
# (700, 121)

# %%
# Compute correlation matrix of numeric columns
corr_matrix = processed_recession_df.select_dtypes(include='number').corr().abs()

# Select upper triangle of correlation matrix without diagonal
upper_tri = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))

# Find pairs with correlation > 0.9
high_corr_pairs = (
    upper_tri.stack()
    .reset_index()
    .rename(columns={0: 'correlation'})
    .query('correlation > 0.9')
    .sort_values(by='correlation', ascending=False)
)

# Print nicely
if not high_corr_pairs.empty:
    print(f"Found {len(high_corr_pairs)} highly correlated feature pairs (correlation > 0.9):\n")
    for idx, row in high_corr_pairs.iterrows():
        print(f"{row['level_0']} ↔ {row['level_1']}: {row['correlation']:.4f}")
else:
    print("No feature pairs found with correlation above 0.9.")

# Save to CSV
high_corr_pairs.to_csv('../data/feature-engineered/high_correlation_pairs.csv', index=False)
print("\nSaved the high correlation pairs to 'high_correlation_pairs.csv'.")
# Out:
# Found 175 highly correlated feature pairs (correlation > 0.9):
#
# CPI ↔ seasonally_adjusted_CPI: 1.0000
# INDPRO ↔ seasonally_adjusted_INDPRO: 1.0000
# CPI ↔ CPI_trend: 0.9999
# seasonally_adjusted_CPI ↔ CPI_trend: 0.9999
# PPI ↔ seasonally_adjusted_PPI: 0.9992
# INDPRO ↔ INDPRO_trend: 0.9986
# seasonally_adjusted_INDPRO ↔ INDPRO_trend: 0.9986
# 3_months_rate_sumsq_acf_original ↔ 6_months_rate_sumsq_acf_original: 0.9985
# 3_months_rate ↔ 6_months_rate: 0.9982
# unemployment_rate ↔ seasonally_adjusted_unemployment_rate: 0.9980
# 1_year_rate ↔ 6_months_rate: 0.9977
# Year ↔ CPI_trend: 0.9959
# CPI ↔ Year: 0.9956
# Year ↔ seasonally_adjusted_CPI: 0.9956
# INDPRO_sumsq_acf_original ↔ gdp_per_capita_sumsq_acf_original: 0.9954
# PPI ↔ PPI_trend: 0.9950
# PPI_trend ↔ seasonally_adjusted_PPI: 0.9943
# Year ↔ gdp_per_capita: 0.9939
# gdp_per_capita ↔ CPI_trend: 0.9929
# 1_year_rate ↔ 3_months_rate: 0.9928
# gdp_per_capita ↔ seasonally_adjusted_CPI: 0.9927
# CPI ↔ gdp_per_capita: 0.9927
# 1_year_rate_sumsq_acf_original ↔ 6_months_rate_sumsq_acf_original: 0.9914
# share_price ↔ gdp_per_capita: 0.9878
# 1_year_rate_sumsq_acf_original ↔ 3_months_rate_sumsq_acf_original: 0.9875
# 1_year_rate_acf1_original ↔ 6_months_rate_acf1_original: 0.9867
# OECD_CLI_index_acf1_diff1 ↔ OECD_CLI_index_acf1_diff2: 0.9865
# INDPRO_acf1_original ↔ gdp_per_capita_acf1_original: 0.9857
# share_price ↔ INDPRO_trend: 0.9833
# INDPRO ↔ share_price: 0.9822
# share_price ↔ seasonally_adjusted_INDPRO: 0.9821
# share_price ↔ Year: 0.9803
# gdp_per_capita ↔ INDPRO_trend: 0.9778
# share_price ↔ CPI_trend: 0.9774
# CPI ↔ share_price: 0.9771
# share_price ↔ seasonally_adjusted_CPI: 0.9771
# INDPRO ↔ gdp_per_capita: 0.9761
# gdp_per_capita ↔ seasonally_adjusted_INDPRO: 0.9761
# 6_months_rate_sumsq_acf_original ↔ 10_year_rate_sumsq_acf_original: 0.9758
# 3_months_rate_acf1_diff2 ↔ 6_months_rate_acf1_diff2: 0.9745
# 1_year_rate_sumsq_acf_original ↔ 10_year_rate_sumsq_acf_original: 0.9735
# Year ↔ INDPRO_trend: 0.9717
# Quarter_Number ↔ Month_Number: 0.9716
# 3_months_rate_acf1_original ↔ 6_months_rate_acf1_original: 0.9706
# OECD_CLI_index_acf1_diff2 ↔ OECD_CLI_index_sumsq_acf_diff2: 0.9704
# 3_months_rate_sumsq_acf_original ↔ 10_year_rate_sumsq_acf_original: 0.9691
# CPI_sumsq_acf_original ↔ 10_year_rate_acf1_original: 0.9688
# INDPRO ↔ Year: 0.9681
# Year ↔ seasonally_adjusted_INDPRO: 0.9681
# 1_year_rate_acf1_original ↔ 10_year_rate_acf1_original: 0.9674
# CPI_sumsq_acf_original ↔ PPI_sumsq_acf_original: 0.9638
# OECD_CLI_index_acf1_diff1 ↔ OECD_CLI_index_sumsq_acf_diff1: 0.9637
# CPI_sumsq_acf_original ↔ gdp_per_capita_sumsq_acf_original: 0.9631
# CPI_acf1_original ↔ share_price_acf1_original: 0.9619
# CPI_trend ↔ INDPRO_trend: 0.9596
# seasonally_adjusted_CPI ↔ INDPRO_trend: 0.9594
# CPI ↔ INDPRO_trend: 0.9594
# 6_months_rate_acf1_original ↔ 10_year_rate_acf1_original: 0.9569
# INDPRO ↔ CPI_trend: 0.9566
# seasonally_adjusted_INDPRO ↔ CPI_trend: 0.9565
# INDPRO ↔ seasonally_adjusted_CPI: 0.9565
# CPI ↔ INDPRO: 0.9565
# seasonally_adjusted_INDPRO ↔ seasonally_adjusted_CPI: 0.9565
# CPI ↔ seasonally_adjusted_INDPRO: 0.9565
# OECD_CLI_index_acf1_original ↔ OECD_CLI_index_sumsq_acf_original: 0.9558
# 6_months_rate_sumsq_acf_original ↔ share_price_sumsq_acf_original: 0.9554
# OECD_CLI_index_acf1_diff1 ↔ OECD_CLI_index_sumsq_acf_diff2: 0.9550
# 10_year_rate_sumsq_acf_original ↔ share_price_sumsq_acf_original: 0.9544
# CPI_sumsq_acf_original ↔ INDPRO_sumsq_acf_original: 0.9520
# CPI_sumsq_acf_original ↔ 10_year_rate_sumsq_acf_original: 0.9501
# CPI_sumsq_acf_original ↔ CSI_index_sumsq_acf_original: 0.9488
# 3_months_rate_sumsq_acf_original ↔ share_price_sumsq_acf_original: 0.9487
# INDPRO_sumsq_acf_original ↔ 10_year_rate_sumsq_acf_original: 0.9478
# 10_year_rate_acf1_original ↔ CSI_index_sumsq_acf_original: 0.9476
# 1_year_rate ↔ 10_year_rate: 0.9468
# 1_year_rate_sumsq_acf_original ↔ share_price_sumsq_acf_original: 0.9459
# 10_year_rate_acf1_original ↔ 10_year_rate_sumsq_acf_original: 0.9449
# Year ↔ 3_months_rate_sumsq_acf_original: 0.9392
# 10_year_rate_sumsq_acf_original ↔ gdp_per_capita_sumsq_acf_original: 0.9379
# CSI_index_sumsq_acf_diff1 ↔ CSI_index_sumsq_acf_diff2: 0.9361
# OECD_CLI_index_sumsq_acf_diff1 ↔ OECD_CLI_index_acf1_diff2: 0.9357
# CPI_acf1_original ↔ INDPRO_acf1_original: 0.9347
# CPI ↔ PPI_trend: 0.9332
# seasonally_adjusted_CPI ↔ PPI_trend: 0.9331
# 6_months_rate_sumsq_acf_original ↔ INDPRO_sumsq_acf_original: 0.9331
# CPI_trend ↔ PPI_trend: 0.9324
# 3_months_rate_acf1_diff1 ↔ 6_months_rate_acf1_diff1: 0.9323
# 1_year_rate_acf1_original ↔ CPI_sumsq_acf_original: 0.9319
# CPI_acf1_original ↔ gdp_per_capita_acf1_original: 0.9317
# CPI_acf1_original ↔ CPI_sumsq_acf_original: 0.9317
# 1_year_rate_acf1_original ↔ 3_months_rate_acf1_original: 0.9317
# CPI_trend ↔ 3_months_rate_sumsq_acf_original: 0.9317
# seasonally_adjusted_CPI ↔ 3_months_rate_sumsq_acf_original: 0.9315
# CPI ↔ 3_months_rate_sumsq_acf_original: 0.9315
# Year ↔ 6_months_rate_sumsq_acf_original: 0.9313
# 1_year_rate_acf1_original ↔ 10_year_rate_sumsq_acf_original: 0.9307
# 1_year_rate_sumsq_acf_diff2 ↔ 6_months_rate_sumsq_acf_diff2: 0.9303
# PPI_acf1_diff1 ↔ PPI_sumsq_acf_diff1: 0.9300
# CPI_acf1_original ↔ 10_year_rate_acf1_original: 0.9297
# CPI_acf1_original ↔ PPI_sumsq_acf_original: 0.9287
# 6_months_rate ↔ 10_year_rate: 0.9284
# anomaly_1_year_rate ↔ anomaly_6_months_rate: 0.9283
# 3_months_rate_sumsq_acf_original ↔ INDPRO_sumsq_acf_original: 0.9273
# CPI_acf1_original ↔ OECD_CLI_index_acf1_original: 0.9267
# unemployment_rate ↔ unemployment_rate_trend: 0.9246
# 10_year_rate_acf1_original ↔ PPI_sumsq_acf_original: 0.9242
# CPI_trend ↔ 6_months_rate_sumsq_acf_original: 0.9242
# seasonally_adjusted_CPI ↔ 6_months_rate_sumsq_acf_original: 0.9241
# CPI ↔ 6_months_rate_sumsq_acf_original: 0.9241
# 1_year_rate_sumsq_acf_original ↔ INDPRO_sumsq_acf_original: 0.9211
# 1_year_rate_acf1_original ↔ 3_months_rate_sumsq_acf_original: 0.9206
# 6_months_rate_acf1_original ↔ CPI_acf1_original: 0.9201
# CPI_sumsq_acf_original ↔ CSI_index_sumsq_acf_diff1: 0.9201
# CPI_acf1_original ↔ CSI_index_sumsq_acf_original: 0.9199
# 6_months_rate_acf1_original ↔ CPI_sumsq_acf_original: 0.9196
# 3_months_rate ↔ 10_year_rate: 0.9194
# seasonally_adjusted_unemployment_rate ↔ unemployment_rate_trend: 0.9193
# 1_year_rate_acf1_original ↔ 6_months_rate_sumsq_acf_original: 0.9193
# 3_months_rate_sumsq_acf_original ↔ CPI_acf1_diff2: 0.9191
# CPI ↔ PPI: 0.9189
# PPI ↔ seasonally_adjusted_CPI: 0.9189
# 10_year_rate_acf1_original ↔ gdp_per_capita_sumsq_acf_original: 0.9188
# gdp_per_capita ↔ PPI_trend: 0.9187
# gdp_per_capita_acf1_diff1 ↔ gdp_per_capita_sumsq_acf_diff1: 0.9184
# CPI ↔ seasonally_adjusted_PPI: 0.9183
# seasonally_adjusted_CPI ↔ seasonally_adjusted_PPI: 0.9183
# 6_months_rate_sumsq_acf_original ↔ CPI_acf1_diff2: 0.9179
# gdp_per_capita ↔ 3_months_rate_sumsq_acf_original: 0.9178
# INDPRO_sumsq_acf_original ↔ share_price_sumsq_acf_original: 0.9178
# PPI ↔ CPI_trend: 0.9177
# PPI_sumsq_acf_original ↔ gdp_per_capita_sumsq_acf_original: 0.9176
# CPI_trend ↔ seasonally_adjusted_PPI: 0.9171
# share_price_sumsq_acf_original ↔ share_price_sumsq_acf_diff2: 0.9166
# 1_year_rate_acf1_original ↔ 1_year_rate_sumsq_acf_original: 0.9159
# INDPRO_sumsq_acf_original ↔ 10_year_rate_acf1_original: 0.9154
# 6_months_rate_sumsq_acf_original ↔ gdp_per_capita_sumsq_acf_original: 0.9150
# Year ↔ PPI_trend: 0.9150
# 3_months_rate_acf1_original ↔ CPI_acf1_original: 0.9139
# Year ↔ 1_year_rate_sumsq_acf_original: 0.9125
# share_price_sumsq_acf_diff1 ↔ gdp_per_capita_sumsq_acf_original: 0.9124
# share_price ↔ 3_months_rate_sumsq_acf_original: 0.9112
# INDPRO_trend ↔ 3_months_rate_sumsq_acf_original: 0.9096
# 3_months_rate_acf1_original ↔ gdp_per_capita_acf1_original: 0.9095
# gdp_per_capita ↔ 6_months_rate_sumsq_acf_original: 0.9092
# recession_probability ↔ 1_month_recession_probability: 0.9091
# CPI_trend ↔ 1_year_rate_sumsq_acf_original: 0.9089
# seasonally_adjusted_CPI ↔ 1_year_rate_sumsq_acf_original: 0.9087
# CPI ↔ 1_year_rate_sumsq_acf_original: 0.9087
# share_price_sumsq_acf_original ↔ gdp_per_capita_sumsq_acf_original: 0.9085
# 3_months_rate_sumsq_acf_original ↔ gdp_per_capita_sumsq_acf_original: 0.9083
# 3_months_rate_acf1_original ↔ INDPRO_acf1_original: 0.9083
# 1_year_rate_sumsq_acf_original ↔ CPI_acf1_diff2: 0.9076
# CPI_sumsq_acf_original ↔ share_price_acf1_original: 0.9075
# seasonally_adjusted_INDPRO ↔ 3_months_rate_sumsq_acf_original: 0.9064
# INDPRO ↔ 3_months_rate_sumsq_acf_original: 0.9063
# 1_year_rate_sumsq_acf_original ↔ gdp_per_capita_sumsq_acf_original: 0.9051
# PPI ↔ gdp_per_capita: 0.9050
# CPI_acf1_original ↔ CSI_index_acf1_original: 0.9049
# share_price ↔ 6_months_rate_sumsq_acf_original: 0.9049
# gdp_per_capita ↔ seasonally_adjusted_PPI: 0.9046
# 3_months_rate_sumsq_acf_original ↔ 6_months_rate_acf1_original: 0.9044
# INDPRO_trend ↔ 6_months_rate_sumsq_acf_original: 0.9036
# 6_months_rate_acf1_original ↔ 10_year_rate_sumsq_acf_original: 0.9032
# 1_year_rate_acf1_original ↔ INDPRO_sumsq_acf_original: 0.9030
# 1_year_rate_acf1_original ↔ CSI_index_sumsq_acf_original: 0.9028
# 6_months_rate_acf1_original ↔ CSI_index_sumsq_acf_original: 0.9027
# CPI_sumsq_acf_original ↔ share_price_sumsq_acf_original: 0.9027
# 10_year_rate_acf1_original ↔ share_price_acf1_original: 0.9021
# 1_year_rate_acf1_original ↔ gdp_per_capita_sumsq_acf_original: 0.9020
# OECD_CLI_index_acf1_original ↔ CSI_index_acf1_original: 0.9015
# seasonally_adjusted_INDPRO ↔ 6_months_rate_sumsq_acf_original: 0.9006
# INDPRO ↔ 6_months_rate_sumsq_acf_original: 0.9005
# share_price_acf1_original ↔ CSI_index_sumsq_acf_original: 0.9002
# PPI ↔ Year: 0.9001
# PPI_sumsq_acf_original ↔ CSI_index_sumsq_acf_diff1: 0.9001
#
# Saved the high correlation pairs to 'high_correlation_pairs.csv'.
